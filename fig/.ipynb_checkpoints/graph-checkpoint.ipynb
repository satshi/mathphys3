# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
using SpecialFunctions

# %%
using LaTeXStrings

# %%
plot(x->besselj(2,x),0,20, label=L"J_2(x)", framestyle = :origin)

# %%
savefig("besselj2.pdf")
